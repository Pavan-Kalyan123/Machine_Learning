# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Load the data sets- train and test 
# Split dataset into 80% training and 20% testing
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Display the shape of datasets
print(f"Train dataset shape: {train_df.shape}")
print(f"Test dataset shape: {test_df.shape}")

# Display first few rows of train dataset
print(train_df.head())
# Out:
# Train dataset shape: (712, 12)
# Test dataset shape: (179, 12)
#      PassengerId  Survived  Pclass                                Name  \
# 331          332         0       1                 Partner, Mr. Austen
# 733          734         0       2          Berriman, Mr. William John
# 382          383         0       3                  Tikkanen, Mr. Juho
# 704          705         0       3             Hansen, Mr. Henrik Juul
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 331    male  45.5      0      0             113043  28.5000  C124        S
# 733    male  23.0      0      0              28425  13.0000   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 704    male  26.0      1      0             350025   7.8542   NaN        S
# 813  female   6.0      4      2             347082  31.2750   NaN        S

# %%
#Look at top values of train data 
print(train_df.head())
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 331          332         0       1                 Partner, Mr. Austen
# 733          734         0       2          Berriman, Mr. William John
# 382          383         0       3                  Tikkanen, Mr. Juho
# 704          705         0       3             Hansen, Mr. Henrik Juul
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 331    male  45.5      0      0             113043  28.5000  C124        S
# 733    male  23.0      0      0              28425  13.0000   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 704    male  26.0      1      0             350025   7.8542   NaN        S
# 813  female   6.0      4      2             347082  31.2750   NaN        S

# %%
#Print the column names of train data
print(train_df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
print(train_df.shape)
print(test_df.shape)
print(df.dtypes)
# Out:
# (712, 12)
# (179, 12)
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Print the number of missing values in each column of train and test data
# Check missing values in train dataset
print("Missing values in Train Dataset:\n", train_df.isnull().sum())

# Check missing values in test dataset
print("\nMissing values in Test Dataset:\n", test_df.isnull().sum())
# Out:
# Missing values in Train Dataset:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            140
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          553
# Embarked         2
# dtype: int64
#
# Missing values in Test Dataset:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             37
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          134
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
import matplotlib.pyplot as plt
import seaborn as sns

plt.subplot(2,2,1)
sns.countplot(data=df,x='Survived',palette='coolwarm')
plt.subplot(2,2,2)
sns.countplot(data=df,x='Pclass',palette='magma')
plt.subplot(2,2,3)
sns.countplot(data=df,x='Sex',palette='pastel')
plt.subplot(2,2,4)
sns.countplot(data=df,x='Embarked',palette='viridis')
plt.show()
# Out:
# /tmp/ipykernel_4278/1102610699.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Survived',palette='coolwarm')
# /tmp/ipykernel_4278/1102610699.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Pclass',palette='magma')
# /tmp/ipykernel_4278/1102610699.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Sex',palette='pastel')
# /tmp/ipykernel_4278/1102610699.py:12: FutureWarning:
#
# ...

# %%
# Set the figure size
plt.figure(figsize=(20, 10))

# Bar chart for Survived
plt.subplot(2, 2, 1)
sns.countplot(x='Survived', data=train_df, palette='pastel')
plt.title('Survival Count')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')

# Bar chart for Pclass
plt.subplot(2, 2, 2)
sns.countplot(x='Pclass', data=train_df, palette='muted')
plt.title('Passenger Class Count')
plt.xlabel('Pclass')
plt.ylabel('Count')

# Bar chart for Sex
plt.subplot(2, 2, 3)
sns.countplot(x='Sex', data=train_df, palette='Set2')
plt.title('Gender Count')
plt.xlabel('Sex')
plt.ylabel('Count')

# Bar chart for Embarked
plt.subplot(2, 2, 4)
sns.countplot(x='Embarked', data=train_df, palette='coolwarm')
plt.title('Port of Embarkation')
plt.xlabel('Embarked')
plt.ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4278/480172668.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=train_df, palette='pastel')
# /tmp/ipykernel_4278/480172668.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=train_df, palette='muted')
# /tmp/ipykernel_4278/480172668.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=train_df, palette='Set2')
# /tmp/ipykernel_4278/480172668.py:27: FutureWarning:
#
# ...

# %%
#Histogram of Age, Parch, Fare
# Plot histogram for Age
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(train_df['Age'], kde=True, color='skyblue')
plt.title('Distribution of Age')

# Plot histogram for Parch
plt.subplot(1, 3, 2)
sns.histplot(train_df['Parch'], bins=10, kde=False, color='lightcoral')
plt.title('Distribution of Parch')

# Plot histogram for Fare
plt.subplot(1, 3, 3)
sns.histplot(train_df['Fare'], bins=40, kde=True, color='lightgreen')
plt.title('Distribution of Fare')

# Display the plots
plt.tight_layout()
plt.show()

# %%
#Plot histogram of age for survived and did not survived class
# Set the figure size
plt.figure(figsize=(10, 5))

# Plot histogram for Age based on Survival
sns.histplot(data=train_df, x='Age', hue='Survived', bins=30, kde=True)

# Add labels and title
plt.title('Age Distribution for Survived and Did Not Survive')
plt.xlabel('Age')
plt.ylabel('Count')

# Show plot
plt.show()

# %%
#Count class and gender wise survival rate - plot with appropriate chart
plt.figure(figsize=(15, 5))

# Plot class-wise survival rate
plt.subplot(1, 2, 1)
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=train_df, palette='pastel')
plt.title('Survival Rate by Class and Gender')
plt.ylabel('Survival Rate')

# Plot gender-wise survival count
plt.subplot(1, 2, 2)
sns.countplot(x='Sex', hue='Survived', data=train_df, palette='viridis')
plt.title('Survival Count by Gender')
plt.ylabel('Count')

# Show plots
plt.tight_layout()
plt.show()

# %%
#Age wise Distribution of Male and Female passengers
plt.figure(figsize=(15, 5))

# Plot age distribution for male passengers
plt.subplot(1, 2, 1)
sns.histplot(train_df[train_df['Sex'] == 'male']['Age'], bins=30, color='lightblue', kde=True)
plt.title('Age Distribution of Male Passengers')
plt.xlabel('Age')
plt.ylabel('Count')

# Plot age distribution for female passengers
plt.subplot(1, 2, 2)
sns.histplot(train_df[train_df['Sex'] == 'female']['Age'], bins=30, color='lightpink', kde=True)
plt.title('Age Distribution of Female Passengers')
plt.xlabel('Age')
plt.ylabel('Count')

# Show plots
plt.tight_layout()
plt.show()

# %%
#Histogram of Age of the given data set(sample)
# Set the figure size
plt.figure(figsize=(10, 5))

# Plot the histogram of Age
sns.histplot(train_df['Age'], bins=30, kde=True, color='skyblue')

# Add labels and title
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the missing values in Embarked column by 'S'
print(train_df['Embarked'].isnull().sum())
train_df['Embarked'] = train_df['Embarked'].fillna('S')

# Verify if missing values are filled
print(train_df['Embarked'].isnull().sum())
# Out:
# 2
# 0

# %%
#Impute the missing values in Fare column with median value
# Fill missing values in Fare column with median value

train_df['Fare'] = train_df['Fare'].fillna(train_df['Fare'].median())
# Verify if missing values are filled
print(train_df['Fare'].isnull().sum())
# Out:
# 0

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
import numpy as np
# Calculate mean and standard deviation of non-missing Age values
mean_age = train_df['Age'].mean()
std_age = train_df['Age'].std()

# Generate random ages for missing values
random_ages = np.random.normal(loc=mean_age, scale=std_age, size=train_df['Age'].isnull().sum())

# Assign these random ages to missing Age values
train_df.loc[train_df['Age'].isnull(), 'Age'] = random_ages

# Verify if missing values are filled
print(train_df['Age'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1

# Create FamilySize Feature
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1

# Display the first few rows to verify
print(train_df[['SibSp', 'Parch', 'FamilySize']].head())
# Out:
#      SibSp  Parch  FamilySize
# 331      0      0           1
# 733      0      0           1
# 382      0      0           1
# 704      1      0           2
# 813      4      2           7

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
# Create IsAlone Feature
train_df['IsAlone'] = (train_df['FamilySize'] == 1)

# Convert Boolean to Integer (Optional)
train_df['IsAlone'] = train_df['IsAlone'].astype(int)

# Display the first few rows to verify
print(train_df[['FamilySize', 'IsAlone']].head())
# Out:
#      FamilySize  IsAlone
# 331           1        1
# 733           1        1
# 382           1        1
# 704           2        0
# 813           7        0

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
# Create Has_cabin Feature
train_df['Has_cabin'] = train_df['Cabin'].notnull()

# Convert Boolean to Integer (Optional)
train_df['Has_cabin'] = train_df['Has_cabin'].astype(int)

# Display the first few rows to verify
print(train_df[['Cabin', 'Has_cabin']].head())
# Out:
#     Cabin  Has_cabin
# 331  C124          1
# 733   NaN          0
# 382   NaN          0
# 704   NaN          0
# 813   NaN          0

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
# Drop irrelevant columns
train_df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# Display the first few rows to verify
print(train_df.head())
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 331         0       1    male  45.5      0      0  28.5000        S
# 733         0       2    male  23.0      0      0  13.0000        S
# 382         0       3    male  32.0      0      0   7.9250        S
# 704         0       3    male  26.0      1      0   7.8542        S
# 813         0       3  female   6.0      4      2  31.2750        S
#
#      FamilySize  IsAlone  Has_cabin
# 331           1        1          1
# 733           1        1          0
# 382           1        1          0
# 704           2        0          0
# 813           7        0          0

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y

# Prepare X (Features) and y (Target)
X = train_df.drop('Survived', axis=1)  # Drop Survived column to create X
y = train_df['Survived']               # Target variable

# Display the shape of X and y
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (712, 10)
# Shape of y: (712,)

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Label Encode Sex column
train_df['Sex'] = le.fit_transform(train_df['Sex'])

# Label Encode Embarked column
train_df['Embarked'] = le.fit_transform(train_df['Embarked'])

# Verify the changes
print(train_df[['Sex', 'Embarked']].head())#C-0,Q-1,S-2
# Out:
#      Sex  Embarked
# 331    1         2
# 733    1         2
# 382    1         2
# 704    1         2
# 813    0         2

# %%
# concat df_categorical with original df
# Concatenate df_categorical with train_df
train_df = pd.concat([train_df, df_categorical], axis=1)

# Verify the shape of the DataFrame
print("Shape of train_df after concatenation:", train_df.shape)

# Display the first few rows to confirm
print(train_df.head())
#error got because i haven't created the df_categorical dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3299/1659829982.py in <module>
#       1 # concat df_categorical with original df
#       2 # Concatenate df_categorical with train_df
# ----> 3 train_df = pd.concat([train_df, df_categorical], axis=1)
#       4
#       5 # Verify the shape of the DataFrame
#
# NameError: name 'df_categorical' is not defined

# %%
#Do a pairplot of all features
# Create a pairplot for all features
sns.pairplot(train_df, hue='Survived', palette='viridis')

# Show the plot
plt.show()

# %%
#X
print(X.dtypes)
# Out:
# Pclass          int64
# Sex            object
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# Embarked       object
# FamilySize      int64
# IsAlone         int64
# Has_cabin       int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Encode categorical columns
train_df['Sex'] = le.fit_transform(train_df['Sex'])
train_df['Embarked'] = le.fit_transform(trai
n_df['Embarked'])

# Now redefine X and y after encoding
X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

# Verify again
print(X.dtypes)
# Out:
# Pclass          int64
# Sex             int64
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# Embarked        int64
# FamilySize      int64
# IsAlone         int64
# Has_cabin       int64
# dtype: object

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
# Split the data into 90% Train and 10% Validation
X_train, X_test, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Display the shape of train and test sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_validation:", y_validation.shape)
# Out:
# Shape of X_train: (640, 10)
# Shape of X_test: (72, 10)
# Shape of y_train: (640,)
# Shape of y_validation: (72,)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, y_train)

train_accuracy = model.score(X_train, y_train)
validation_accuracy = model.score(X_test, y_validation)

print("Training Accuracy:", round(train_accuracy * 100, 2), "%")
print("Validation Accuracy:", round(validation_accuracy * 100, 2), "%")
# Out:
# Training Accuracy: 99.06 %
# Validation Accuracy: 77.78 %

# %%
#Print the tree

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

plot_tree(model, 
          feature_names=X.columns,  # Column names
          class_names=['Not Survived', 'Survived'],  # Target classes
          filled=True,  # Fill the nodes with color
          rounded=True, # Rounded corners
          fontsize=10)  # Font size

# Show the plot
plt.show()

# %%
# plotting tree with max_depth=3
plt.figure(figsize=(20,10))

# Plot the Decision Tree with max_depth=3
plot_tree(model, 
          feature_names=X.columns,  
          class_names=['Not Survived', 'Survived'],  
          filled=True,  
          rounded=True,  
          fontsize=10,
          max_depth=3)  # <-- Limiting the depth to 3

# Show the plot
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Make predictions on the validation set
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_validation, y_pred)
print("Confusion Matrix:\n", cm)

# Accuracy Score
accuracy = accuracy_score(y_validation, y_pred)
print("\nAccuracy:", round(accuracy * 100, 2), "%")

# Classification Report
report = classification_report(y_validation, y_pred)
print("\nClassification Report:\n", report)
# Out:
# Confusion Matrix:
#  [[35  7]
#  [ 9 21]]
#
# Accuracy: 77.78 %
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81        42
#            1       0.75      0.70      0.72        30
#
#     accuracy                           0.78        72
#    macro avg       0.77      0.77      0.77        72
# weighted avg       0.78      0.78      0.78        72

# %%
# Printing confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score

# Make predictions on the validation set
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_validation, y_pred)
print("Confusion Matrix:")
print(cm)

# Accuracy Score
accuracy = accuracy_score(y_validation, y_pred)
print("\nAccuracy:", round(accuracy * 100, 2), "%")
# Out:
# Confusion Matrix:
# [[35  7]
#  [ 9 21]]
#
# Accuracy: 77.78 %
